# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

import statistics
import requests
import time
import math
from scipy import stats
from pprint import pprint

# Import API key
from api_keys import api_key

#import ready packages
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
#Using existing alpha_vantage packages:

ccb = CryptoCurrencies(key=api_key, output_format='pandas')
b_data, b_meta_data = ccb.get_digital_currency_daily(symbol='BTC', market='USD')

cce = CryptoCurrencies(key=api_key, output_format='pandas')
e_data, e_meta_data = cce.get_digital_currency_daily(symbol='ETH', market='USD')

# %%
b_data.head(1)
# Out:
#             1a. open (USD)  1b. open (USD)  2a. high (USD)  2b. high (USD)  \
# date
# 2021-11-08        63273.58        63273.58         64790.0         64790.0
#
#             3a. low (USD)  3b. low (USD)  4a. close (USD)  4b. close (USD)  \
# date
# 2021-11-08       63273.58       63273.58          64671.9          64671.9
#
#              5. volume  6. market cap (USD)
# date
# 2021-11-08  5431.57406           5431.57406

# %%
b_close = b_data.drop(columns = ['1a. open (USD)', '1b. open (USD)', '2a. high (USD)', '2b. high (USD)',
       '3a. low (USD)', '3b. low (USD)', '4a. close (USD)',
       '5. volume', '6. market cap (USD)'])
e_close = e_data.drop(columns = ['1a. open (USD)', '1b. open (USD)', '2a. high (USD)', '2b. high (USD)',
       '3a. low (USD)', '3b. low (USD)', '4a. close (USD)',
       '5. volume', '6. market cap (USD)'])

# %%
b_close = b_close.rename(columns = {'4b. close (USD)' : 'BTC (USD)'})
e_close = e_close.rename(columns = {'4b. close (USD)' : 'ETH (USD)'})
crypto_data = pd.concat([b_close, e_close], axis = 1)
crypto_data.head(1)
# Out:
#             BTC (USD)  ETH (USD)
# date
# 2021-11-08    64671.9    4671.34

# %%
crypto_data.corr()
# Out:
#            BTC (USD)  ETH (USD)
# BTC (USD)   1.000000   0.921622
# ETH (USD)   0.921622   1.000000

# %%
def plot_correlations(df, roll):
    columns = df.columns.to_list()
    
    fig, ax = plt.subplots(2,1, figsize = (15, 9))
    
    ax[0].plot(df.index, df[columns[0]], c = 'r')
    ax[0].set_ylabel(f'Price of {columns[0]}', color = 'r')
    ax[0].tick_params('y', colors = 'r')

    ax2 = ax[0].twinx()
    ax2.plot(df.index, df[columns[1]], c = 'b')
    ax2.set_ylabel(f'Price of {columns[1]}', color = 'b')
    ax2.tick_params('y', colors = 'b')
    
    ax[1].plot(df[columns[0]].rolling(window = 45).corr(df[columns[1]]))
    ax[1].axhline(df.corr().iloc[0,1], c = 'r')
    ax[1].set_ylabel('45 day rolling correlation between' '\n' f'{columns[0]} and {columns[1]} prices')
    ax[1].annotate('global correlation coefficient', 
               xy = [pd.Timestamp('2019-01'), df.corr().iloc[0,1]], xytext = [pd.Timestamp('2019-05'), 0.2], arrowprops = {})
    
    print(df.corr())

# %%
plot_correlations(crypto_data, 45)
# Out:
#            BTC (USD)  ETH (USD)
# BTC (USD)   1.000000   0.921622
# ETH (USD)   0.921622   1.000000

# %%
plt.figure(figsize=(5, 4))
sns.lmplot(x="BTC (USD)", y="ETH (USD)", data=crypto_data, height=6, aspect=2.5)
plt.title("Linear Regression Model to determine the Correlation between BTC and ETH prices from 11FEB2019 to 06NOV2021", fontsize=16)
plt.show()

# %%
ts = TimeSeries(key= api_key, output_format='pandas')
spy_data, spy_meta_data = ts.get_daily(symbol='SPY', outputsize='full')
spy_close = spy_data.drop(columns = ['1. open', '2. high', '3. low', '5. volume'])
spy_close = spy_close.rename(columns = {'4. close': 'SPY (USD)'})
spy_btc_data = b_close.join(spy_close, how = 'inner')
spy_btc_data.tail(1)
# Out:
#             BTC (USD)  SPY (USD)
# date
# 2019-02-13     3609.4     274.99

# %%
plot_correlations(spy_btc_data, 45)
# Out:
#            BTC (USD)  SPY (USD)
# BTC (USD)   1.000000   0.894286
# SPY (USD)   0.894286   1.000000

# %%
# Out:
#            BTC (USD)  SPY (USD)
# BTC (USD)   1.000000   0.894286
# SPY (USD)   0.894286   1.000000

# %%
hive_data, hive_meta_data = ts.get_daily(symbol='HIVE', outputsize='full')
hive_close = hive_data.drop(columns = ['1. open', '2. high', '3. low', '5. volume'])
hive_close = hive_close.rename(columns = {'4. close': 'HIVE (USD)'})
hive_btc_data = b_close.join(hive_close, how = 'inner')
hive_btc_data.tail(1)
# Out:
#             BTC (USD)  HIVE (USD)
# date
# 2019-02-13     3609.4       0.294

# %%
plot_correlations(hive_btc_data, 45)
# Out:
#             BTC (USD)  HIVE (USD)
# BTC (USD)    1.000000    0.972767
# HIVE (USD)   0.972767    1.000000

# %%
hive_spy_data = spy_close.join(hive_close, how = 'inner')
hive_spy_data.tail(1)
# Out:
#             SPY (USD)  HIVE (USD)
# date
# 2018-01-12     277.92        2.64

# %%
plot_correlations(hive_spy_data, 45)
# Out:
#             SPY (USD)  HIVE (USD)
# SPY (USD)    1.000000    0.780627
# HIVE (USD)   0.780627    1.000000

# %%
bbkcf_data, bbkcf_meta_data = ts.get_daily(symbol='BBKCF', outputsize='full')
bbkcf_close = bbkcf_data.drop(columns = ['1. open', '2. high', '3. low', '5. volume'])
bbkcf_close = bbkcf_close.rename(columns = {'4. close': 'BBKCF (USD)'})
bbkcf_btc_data = b_close.join(bbkcf_close, how = 'inner')
bbkcf_btc_data.tail(1)
# Out:
#             BTC (USD)  BBKCF (USD)
# date
# 2019-02-13     3609.4       0.0667

# %%
plot_correlations(bbkcf_btc_data, 45)
# Out:
#              BTC (USD)  BBKCF (USD)
# BTC (USD)     1.000000     0.887539
# BBKCF (USD)   0.887539     1.000000

# %%
bbkcf_spy_data = spy_close.join(bbkcf_close, how = 'inner')
bbkcf_spy_data.tail(1)
# Out:
#             SPY (USD)  BBKCF (USD)
# date
# 2017-12-12     266.78       1.4028

# %%
plot_correlations(bbkcf_spy_data, 45)
# Out:
#              SPY (USD)  BBKCF (USD)
# SPY (USD)     1.000000     0.647477
# BBKCF (USD)   0.647477     1.000000
